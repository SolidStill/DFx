# %% [markdown]
# <a href="https://colab.research.google.com/github/SolidStill/DFx/blob/main/XenoCantoAPI_to_CSV%26HTML_map.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import numpy as np
import pandas as pd
import folium

""" below fn get_recent_for_country() queries the API for all recordings
from specified country - this is excessive and limited by API: comprehensive solution
would ensure all relevant entries from API's database are extracted.
See https://xeno-canto.org/explore/api API documentation for further details on
how to handle this.
"""

def get_recent_for_country(chosen_country, n):

    # API query string to return bird song recordings for a specified country
    url = f'https://xeno-canto.org/api/2/recordings?query=cnt:{chosen_country}'

    # send an HTTP GET request to the URL stored in the url variable
    response = requests.get(url)

    # parses JSON into a dict object using .json() method from 'requests' lib
    country_dict = response.json()

    # selects the relevant part of the response (where the actual juicy data is)
    country_recordings_list = country_dict['recordings'] # this a list of dicts

    # constructs dataframe using all columns in API response
    recordings_df = pd.DataFrame(country_recordings_list)

    # selects columns of particular interest and in the desired order
    selected_columns = ['en','url','file','sono','date','loc','lat','lng','id']
    selected_columns_df = recordings_df[selected_columns]


    # sorts by date - "ascending=False" for newest at top & oldest at bottom
    date_sorted_df = selected_columns_df.sort_values(by='date', ascending=False)

    # selects only the 'n' newest records,
    user_selected_dates_df = date_sorted_df.iloc[:int(n)]

    # changing column names to something more readable and unambiguous
    new_column_names = {
    'en': 'species_name',
    'url': 'recording_webpage_url',
    'file': 'audio_file_download_link',
    'sono': 'full_sonogram', # later in this function, all but the 'full' dict value from the original response's 4 dict entries under 'sono' will be removed
    'date': 'recording_date',
    'loc': 'general_location',
    'lat': 'latitude',
    'lng': 'longitude',
    'id': 'xeno_canto_recording_id'
    }

    column_name_change_df = user_selected_dates_df.rename(columns=new_column_names)

    # each 'full_sonogram' entry is a dict of 4 sizes of sonogram, this changes the entry to the URL of the largest "full" sonogram only
    column_name_change_df['full_sonogram'] = column_name_change_df['full_sonogram'].apply(lambda x: x.get("full"))

    # ensures the 'recording_webpage_url' and 'full_sonogram' column entries are prepended by 'https:'
    # (Currently, all webpage URLs I can see are starting with '//')
    columns_to_modify = ['recording_webpage_url', 'full_sonogram']

    for column in columns_to_modify:
        column_name_change_df[column] = column_name_change_df[column].astype(str).apply(
            lambda x: 'https:' + x if not x.startswith('https:') else x
        )

    # Convert latitude and longitude to numeric, but fill errors with NaN
    # (this means if conversion fails, the entry will be set to NaN and we can drop it later)
    for column in ['latitude', 'longitude']:
        column_name_change_df[column] = pd.to_numeric(column_name_change_df[column], errors='coerce')

    final_user_df = column_name_change_df

    return final_user_df

from jinja2 import Template

def plot_recordings_map(selected_recordings_df, map_filename_prefix):
    """Generates a Folium map with clickable audio and separate sonogram modals."""

    selected_recordings_df = selected_recordings_df.dropna(subset=['latitude', 'longitude'])

    mean_lat = selected_recordings_df['latitude'].mean()
    mean_lon = selected_recordings_df['longitude'].mean()

    bird_map = folium.Map(location=[mean_lat, mean_lon], zoom_start=5)

    # Create a common modal template outside the loop
    sonogram_modal_template = Template("""
        <div id="sonogramModal{{ index }}" class="modal">
            <div class="modal-content">
                <span class="close-button" onclick="closeModal('sonogramModal{{ index }}')">&times;</span>
                <img class="sonogram-image" src="{{ full_sonogram }}">
            </div>
        </div>
    """)

    # Add markers for each recording
    for index, row in selected_recordings_df.iterrows():
        audio_html = f"""
            <audio controls>
                <source src="{row['audio_file_download_link']}" type="audio/mpeg">
                Your browser does not support the audio element.
            </audio>
        """

        # Button to trigger the modal
        button_html = f"""
            <button onclick="openModal('sonogramModal{index}')">View Sonogram</button>
        """

        popup_html = f"""
            <div class="popup-content">
                <h3>{row['species_name']}</h3>
                <p>Date: {row['recording_date']}</p>
                <p>Location: {row['general_location']}</p>
                {audio_html}
                {button_html}
            </div>
        """

        # Add the modal HTML to the map's root
        bird_map.get_root().html.add_child(folium.Element(
            sonogram_modal_template.render(index=index, full_sonogram=row['full_sonogram'])
        ))

        popup = folium.Popup(html=popup_html, max_width=300)

        folium.Marker(
            location=[row['latitude'], row['longitude']],
            popup=popup,
            icon=folium.Icon(color="green"),
        ).add_to(bird_map)

    # Add the JavaScript to the map header
    js = """
    <script>
        function openModal(modalId) {
            var modal = document.getElementById(modalId);
            if (modal) {
                modal.style.display = "flex";
            } else {
                console.error("Modal not found:", modalId);
            }
        }

        function closeModal(modalId) {
            var modal = document.getElementById(modalId);
            if (modal) {
                modal.style.display = "none";
            } else {
                console.error("Modal not found:", modalId);
            }
        }

        // Close modal when clicking outside of it
        window.onclick = function(event) {
            if (event.target.className === "modal") {
                event.target.style.display = "none";
            }
        }
    </script>
    """
    bird_map.get_root().html.add_child(folium.Element(js))

    # Add CSS styles to the map for the modal
    css = """
    <style>
        /* Basic popup styling */
        .popup-content {
            overflow-y: auto;
        }

        /* Modal styles */
        .modal {
            display: none;
            position: fixed;
            z-index: 1000;
            left: 0;
            top: 0;
            width: 100%;
            height: 100%;
            overflow: auto;
            background-color: rgba(0,0,0,0.9);
            justify-content: center;
            align-items: center;
        }

        .modal-content {
            position: relative;
            background-color: transparent;
            margin: auto;
            padding: 0;
            width: 90%;
            max-width: 100vw;
            display: flex;
            justify-content: center;
            align-items: center;
        }

        .sonogram-image {
            max-width: 100%;
            max-height: 90vh;
            object-fit: contain;
        }

        .close-button {
            color: #f1f1f1;
            position: absolute;
            top: 10px;
            right: 25px;
            font-size: 35px;
            font-weight: bold;
            cursor: pointer;
            z-index: 1001;
        }

        .close-button:hover,
        .close-button:focus {
            color: #bbb;
            text-decoration: none;
            cursor: pointer;
        }
    </style>
    """
    bird_map.get_root().header.add_child(folium.Element(css))

    # Save the map to an HTML file
    bird_map.save(map_filename_prefix)
    print(f"Map saved as {map_filename_prefix}")











""" RE below country input: need to improve UX for this string input; beyond just using .lower() and similar methods.
i.e. ideally something like elastic search interface w/ dropdown selectability
"""
user_chosen_country = input('Which country (e.g. italy) would you like to find recordings from?: '.lower())

# RE below number of records input: specific date range would be a strong improvement
user_number_of_most_recent_recordings = input('How many of the most recent recordings would you like to view?: ')

# generates the final specified dataframe and assigns to 'user_birdsong_df'
user_birdsong_df = get_recent_for_country(user_chosen_country, user_number_of_most_recent_recordings)

# resets the index so the rows are numbered according to their date of recording
user_birdsong_df.reset_index(drop=True, inplace=True)

# display the dataframe
print(user_birdsong_df)

# user input for filename prefixes - user's API parameters appended to name
prefix = (
    input("Choose a name prefix for the CSV and map files: ")
    + "_"
    + user_chosen_country
    + "_"
    + user_number_of_most_recent_recordings
)
# this outputs a CSV from the final form of user_birdsong_df
# index=False to remove the pandas index column from the output as this doesn't seem helpful to include
user_birdsong_df.to_csv(prefix+".csv",index=False)

# generates folium html with map of recording locations
plot_recordings_map(user_birdsong_df, prefix+".html")
# Out:
# which country (e.g. italy) would you like to find recordings from?: italy
# How many of the most recent recordings would you like to view?: 42
#               species_name          recording_webpage_url  \
# 0             Alpine Swift  https://xeno-canto.org/912141
# 1            Common Cuckoo  https://xeno-canto.org/911721
# 2       Common Wood Pigeon  https://xeno-canto.org/911870
# 3   Eurasian Collared Dove  https://xeno-canto.org/909830
# 4            Common Cuckoo  https://xeno-canto.org/910012
# 5   Eurasian Collared Dove  https://xeno-canto.org/909839
# 6             Pallid Swift  https://xeno-canto.org/909107
# 7             Pallid Swift  https://xeno-canto.org/909106
# 8             Common Swift  https://xeno-canto.org/907036
# 9            Common Cuckoo  https://xeno-canto.org/910475
# 10           Common Cuckoo  https://xeno-canto.org/906248
# 11       Barbary Partridge  https://xeno-canto.org/901725
# 12       Barbary Partridge  https://xeno-canto.org/901727
# 13            Alpine Swift  https://xeno-canto.org/900506
# 14           Common Cuckoo  https://xeno-canto.org/902270
# 15      Common Wood Pigeon  https://xeno-canto.org/902259
# 16         Common Shelduck  https://xeno-canto.org/902272
# 17  Eurasian Collared Dove  https://xeno-canto.org/902250
# 18      Common Wood Pigeon  https://xeno-canto.org/902249
# 19      Common Wood Pigeon  https://xeno-canto.org/902244
# 20           Greylag Goose  https://xeno-canto.org/902239
# 21           Eurasian Teal  https://xeno-canto.org/902236
# 22              Swan Goose  https://xeno-canto.org/897210
# 23        Ferruginous Duck  https://xeno-canto.org/893935
# 24    Great Spotted Cuckoo  https://xeno-canto.org/893377
# 25         Common Shelduck  https://xeno-canto.org/882121
# 26           Eurasian Teal  https://xeno-canto.org/879150
# 27         Eurasian Wigeon  https://xeno-canto.org/875528
# 28       Northern Shoveler  https://xeno-canto.org/872818
# 29           Eurasian Teal  https://xeno-canto.org/872816
# 30          Egyptian Goose  https://xeno-canto.org/857424
# 31          Common Pochard  https://xeno-canto.org/839821
# 32            Alpine Swift  https://xeno-canto.org/841735
# 33  Eurasian Collared Dove  https://xeno-canto.org/854573
# 34            Hazel Grouse  https://xeno-canto.org/831783
# 35          Grey Partridge  https://xeno-canto.org/831786
# 36          Rock Ptarmigan  https://xeno-canto.org/829715
# 37            Alpine Swift  https://xeno-canto.org/841588
# 38          Rock Partridge  https://xeno-canto.org/822201
# 39  Eurasian Collared Dove  https://xeno-canto.org/822210
# 40          Rock Partridge  https://xeno-canto.org/822202
# 41            Alpine Swift  https://xeno-canto.org/910225
#
#                   audio_file_download_link  \
# 0   https://xeno-canto.org/912141/download
# 1   https://xeno-canto.org/911721/download
# 2   https://xeno-canto.org/911870/download
# 3   https://xeno-canto.org/909830/download
# 4   https://xeno-canto.org/910012/download
# 5   https://xeno-canto.org/909839/download
# 6   https://xeno-canto.org/909107/download
# 7   https://xeno-canto.org/909106/download
# 8   https://xeno-canto.org/907036/download
# 9   https://xeno-canto.org/910475/download
# 10  https://xeno-canto.org/906248/download
# 11  https://xeno-canto.org/901725/download
# 12  https://xeno-canto.org/901727/download
# 13  https://xeno-canto.org/900506/download
# 14  https://xeno-canto.org/902270/download
# 15  https://xeno-canto.org/902259/download
# 16  https://xeno-canto.org/902272/download
# 17  https://xeno-canto.org/902250/download
# 18  https://xeno-canto.org/902249/download
# 19  https://xeno-canto.org/902244/download
# 20  https://xeno-canto.org/902239/download
# 21  https://xeno-canto.org/902236/download
# 22  https://xeno-canto.org/897210/download
# 23  https://xeno-canto.org/893935/download
# 24  https://xeno-canto.org/893377/download
# 25  https://xeno-canto.org/882121/download
# 26  https://xeno-canto.org/879150/download
# 27  https://xeno-canto.org/875528/download
# 28  https://xeno-canto.org/872818/download
# 29  https://xeno-canto.org/872816/download
# 30  https://xeno-canto.org/857424/download
# 31  https://xeno-canto.org/839821/download
# 32  https://xeno-canto.org/841735/download
# 33  https://xeno-canto.org/854573/download
# 34  https://xeno-canto.org/831783/download
# 35  https://xeno-canto.org/831786/download
# 36  https://xeno-canto.org/829715/download
# 37  https://xeno-canto.org/841588/download
# 38  https://xeno-canto.org/822201/download
# 39  https://xeno-canto.org/822210/download
# 40  https://xeno-canto.org/822202/download
# 41  https://xeno-canto.org/910225/download
#
#                                         full_sonogram recording_date  \
# 0   https://xeno-canto.org/sounds/uploaded/RARNEHK...     2024-06-10
# 1   https://xeno-canto.org/sounds/uploaded/ITHRUQE...     2024-06-09
# 2   https://xeno-canto.org/sounds/uploaded/ITHRUQE...     2024-06-08
# 3   https://xeno-canto.org/sounds/uploaded/ITHRUQE...     2024-06-02
# 4   https://xeno-canto.org/sounds/uploaded/FDRIKER...     2024-06-02
# 5   https://xeno-canto.org/sounds/uploaded/ITHRUQE...     2024-06-02
# 6   https://xeno-canto.org/sounds/uploaded/HVBWFBB...     2024-05-30
# 7   https://xeno-canto.org/sounds/uploaded/HVBWFBB...     2024-05-30
# 8   https://xeno-canto.org/sounds/uploaded/DNZYZSR...     2024-05-26
# 9   https://xeno-canto.org/sounds/uploaded/SUEWHZI...     2024-05-26
# 10  https://xeno-canto.org/sounds/uploaded/ITHRUQE...     2024-05-12
# 11  https://xeno-canto.org/sounds/uploaded/HNYFHZL...     2024-05-10
# 12  https://xeno-canto.org/sounds/uploaded/HNYFHZL...     2024-05-10
# 13  https://xeno-canto.org/sounds/uploaded/HNYFHZL...     2024-05-05
# 14  https://xeno-canto.org/sounds/uploaded/YIHILMT...     2024-04-26
# 15  https://xeno-canto.org/sounds/uploaded/YIHILMT...     2024-04-22
# 16  https://xeno-canto.org/sounds/uploaded/YIHILMT...     2024-04-21
# 17  https://xeno-canto.org/sounds/uploaded/YIHILMT...     2024-04-21
# 18  https://xeno-canto.org/sounds/uploaded/YIHILMT...     2024-04-21
# 19  https://xeno-canto.org/sounds/uploaded/YIHILMT...     2024-04-21
# 20  https://xeno-canto.org/sounds/uploaded/YIHILMT...     2024-04-20
# 21  https://xeno-canto.org/sounds/uploaded/YIHILMT...     2024-04-20
# 22  https://xeno-canto.org/sounds/uploaded/HVBWFBB...     2024-04-19
# 23  https://xeno-canto.org/sounds/uploaded/HVBWFBB...     2024-04-06
# 24  https://xeno-canto.org/sounds/uploaded/VCWOLAE...     2024-04-04
# 25  https://xeno-canto.org/sounds/uploaded/OUALYKR...     2024-03-16
# 26  https://xeno-canto.org/sounds/uploaded/VWWRQKF...     2024-03-02
# 27  https://xeno-canto.org/sounds/uploaded/ITHRUQE...     2024-02-18
# 28  https://xeno-canto.org/sounds/uploaded/HVBWFBB...     2024-02-10
# 29  https://xeno-canto.org/sounds/uploaded/HVBWFBB...     2024-02-10
# 30  https://xeno-canto.org/sounds/uploaded/VWVVYWS...     2023-12-05
# 31  https://xeno-canto.org/sounds/uploaded/HVBWFBB...     2023-11-01
# 32  https://xeno-canto.org/sounds/uploaded/TMIGGIC...     2023-10-23
# 33  https://xeno-canto.org/sounds/uploaded/SVWDAKE...     2023-10-12
# 34  https://xeno-canto.org/sounds/uploaded/LEOULDC...     2023-09-20
# 35  https://xeno-canto.org/sounds/uploaded/LEOULDC...     2023-09-18
# 36  https://xeno-canto.org/sounds/uploaded/URREFGV...     2023-09-15
# 37  https://xeno-canto.org/sounds/uploaded/TMIGGIC...     2023-08-17
# 38  https://xeno-canto.org/sounds/uploaded/HVBWFBB...     2023-08-12
# 39  https://xeno-canto.org/sounds/uploaded/ITHRUQE...     2023-08-12
# 40  https://xeno-canto.org/sounds/uploaded/HVBWFBB...     2023-08-12
# 41  https://xeno-canto.org/sounds/uploaded/TMIGGIC...     2023-07-28
#
#                                      general_location  latitude  longitude  \
# 0              Cossato, Provincia di Biella, Piemonte   45.5697     8.1804
# 1         Bocchigliero, Province of Cosenza, Calabria   39.4043    16.7093
# 2   Corigliano-Rossano, Provincia di Cosenza, Cala...   39.5933    16.6341
# 3   Corigliano-Rossano (near  Amica), Provincia di...   39.6021    16.6810
# 4   Ravenna (near  Sant'Alberto), Province of Rave...   44.5494    12.1558
# 5   Corigliano-Rossano (near  Pantano Martucci), P...   39.6214    16.7578
# 6              Pescara, Provincia di Pescara, Abruzzo   42.4636    14.1997
# 7              Pescara, Provincia di Pescara, Abruzzo   42.4636    14.1997
# 8               Leno, Provincia di Brescia, Lombardia   45.3680    10.2179
# 9      Lecce nei Marsi, Province of L'Aquila, Abruzzo   41.8637    13.7288
# 10        Bocchigliero, Province of Cosenza, Calabria   39.3827    16.7077
# 11  Regional Natural Park of Porto Conte, Province...   40.6146     8.2167
# 12  Regional Natural Park of Porto Conte, Province...   40.6146     8.2167
# 13  Scala di accesso alle Grotte di Nettuno (Escal...   40.5632     8.1636
# 14  Grado, Provincia di Gorizia, Friuli-Venezia Gi...   45.6799    13.4042
# 15  Grado, Provincia di Gorizia, Friuli-Venezia Gi...   45.6799    13.4042
# 16  Grado, Provincia di Gorizia, Friuli-Venezia Gi...   45.6799    13.4042
# 17  Grado, Provincia di Gorizia, Friuli-Venezia Gi...   45.6799    13.4042
# 18  Grado, Provincia di Gorizia, Friuli-Venezia Gi...   45.6799    13.4042
# 19  Grado, Provincia di Gorizia, Friuli-Venezia Gi...   45.6799    13.4042
# 20  Grado, Provincia di Gorizia, Friuli-Venezia Gi...   45.6799    13.4042
# 21  Grado, Provincia di Gorizia, Friuli-Venezia Gi...   45.6799    13.4042
# 22                               Foce del Tordino, TE   42.7397    13.9797
# 23  Sentina Natural Regional Reserve, San Benedett...   42.9037    13.9077
# 24  Dorgali (near  Cala Gonone), Provincia di Nuor...   40.2793     9.6293
# 25                Sacca di Scardovari, Rovigo, Veneto   44.8972    12.4183
# 26    Oasis of Ca 'Mello, Provincia di Rovigo, Veneto   44.8909    12.3994
# 27              Tarsia, Province of Cosenza, Calabria   39.6094    16.2934
# 28  Sentina Natural Regional Reserve, San Benedett...   42.9037    13.9077
# 29  Sentina Natural Regional Reserve, San Benedett...   42.9037    13.9077
# 30   Firenze, Città Metropolitana di Firenze, Toscana   43.7690    11.2519
# 31          Campotosto, Province of L'Aquila, Abruzzo   42.5465    13.3706
# 32  San Giovanni in Fiore, Provincia di Cosenza, C...   39.2599    16.7014
# 33     Barumini, Provincia del Sud Sardegna, Sardegna   39.7061     8.9911
# 34   Sauris, Province of Udine, Friuli-Venezia Giulia   46.4492    12.6353
# 35  Sedegliano (near  Grions), Ente di decentramen...   46.0422    12.9675
# 36  Stilfs, Autonomous Province of Bolzano – South...   46.5246    10.4548
# 37  Zona industriale (near  San Giovanni in Fiore)...   39.2711    16.6766
# 38                               Valle Castellana, TE   42.7790    13.5782
# 39  Corigliano-Rossano (near  Rossano Stazione), P...   39.5947    16.6358
# 40                               Valle Castellana, TE   42.7790    13.5782
# 41  San Giovanni in Fiore, Provincia di Cosenza, C...   39.2568    16.6974
#
#    xeno_canto_recording_id
# 0                   912141
# 1                   911721
# 2                   911870
# 3                   909830
# 4                   910012
# 5                   909839
# 6                   909107
# 7                   909106
# 8                   907036
# 9                   910475
# 10                  906248
# 11                  901725
# 12                  901727
# 13                  900506
# 14                  902270
# 15                  902259
# 16                  902272
# 17                  902250
# 18                  902249
# 19                  902244
# 20                  902239
# 21                  902236
# 22                  897210
# 23                  893935
# 24                  893377
# 25                  882121
# 26                  879150
# 27                  875528
# 28                  872818
# 29                  872816
# 30                  857424
# 31                  839821
# 32                  841735
# 33                  854573
# 34                  831783
# 35                  831786
# 36                  829715
# 37                  841588
# 38                  822201
# 39                  822210
# 40                  822202
# 41                  910225
# Choose a name prefix for the CSV and map files: owliphino
# Map saved as owliphino_italy_42.html
